# %%
#SQLite DB connectivity with python

# %% [markdown]
# testDB Database created in SQLite DB, using DB Browser

# %% [markdown]
# ![SQLite.PNG](attachment:SQLite.PNG)

# %% [markdown]
# Data Base connection explained below needs sqlite3 module

# %%
pip install sqlite3
# Out:
# ERROR: Could not find a version that satisfies the requirement sqlite3 (from versions: none)
# ERROR: No matching distribution found for sqlite3

# %%
import sqlite3

# %%
 #as SQLite is a inmemory DB, we don't need to specify server and driver details

# %%
cnxn_str = ("testDB.db")

# %%
connection = sqlite3.connect(cnxn_str)

# %%
cursor = connection.cursor()
for i in cursor.execute("SELECT  * FROM Employee"):
    print(i)
# Out:
# (1002, 'Kiran', 'A-')
# (1003, 'Tej', 'B-')

# %%
cursor.close()
connection.close()
